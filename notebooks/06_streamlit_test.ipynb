# %%
import pandas as pd
import numpy as np

# %%
from src.utils.loader import load_all_data

data = load_all_data()

# %%
for name, df in data.items():
    print(name, df.shape)
# Out:
# model_df (29240, 24)
# timeseries (29240, 45)
# sarimax_short (120, 5)
# sarimax_long (1200, 5)
# sarimax_future (1200, 4)
# xgb_future (1200, 4)
# staffing (1200, 9)

# %%
model_df = data["model_df"]

timeseries = data["timeseries"]

sarimax_short = data["sarimax_short"]

sarimax_long = data["sarimax_long"]

sarimax_future = data["sarimax_future"]

xgb_future = data["xgb_future"]

staffing = data["staffing"]

# %%
print(sarimax_future.columns)
# Out:
# Index(['hospital_id', 'ward', 'date', 'forecast_occupied_beds'], dtype='str')

# %%
print("SARIMAX short")
print(sarimax_short.columns)


print("\nSARIMAX long")
print(sarimax_long.columns)


print("\nXGBoost future")
print(xgb_future.columns)


print("\nStaffing")
print(staffing.columns)


print("\nModel dataframe")
print(model_df.columns)
# Out:
# SARIMAX short
# Index(['hospital_id', 'ward', 'date', 'actual_occupied_beds',
#        'predicted_occupied_beds'],
#       dtype='str')
#
# SARIMAX long
# Index(['hospital_id', 'ward', 'date', 'actual_occupied_beds',
#        'predicted_occupied_beds'],
#       dtype='str')
#
# XGBoost future
# Index(['hospital_id', 'ward', 'date', 'predicted_occupied_beds'], dtype='str')
#
# Staffing
# Index(['hospital_id', 'ward', 'date', 'predicted_occupied_beds',
#        'planned_staff', 'actual_staff', 'safe_ratio_met', 'staffing_ratio',
#        'staffing_risk'],
#       dtype='str')
#
# Model dataframe
# Index(['hospital_id', 'ward', 'bed_type', 'date', 'total_beds', 'staffed_beds',
#        'occupied_beds', 'closed_beds', 'occupancy_rate', 'available_beds',
#        'daily_admissions', 'avg_los_hours', 'emergency_admissions',
#        'planned_staff', 'actual_staff', 'staffing_ratio', 'daily_ed_arrivals',
#        'scheduled_surgeries', 'hospital_name', 'city', 'tier',
# ...
